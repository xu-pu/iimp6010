# %% [markdown]
# # Welcome to IIMP6010
#
# Welcome to IIMP6010!
#
# This is [Jupyter Notebook](https://en.wikipedia.org/wiki/Project_Jupyter), a common tool used by the scientific community, especially in data science, machine learning and robotics.
#
# You can write python code here in a browser with no addtional setup. Your code will be executed on a remote server hosted by the IIMP6010 teaching team.
#
# Any device/operating system with a browser is suffice, even on an iPad.

# %% [markdown]
# ## Introduction
# Now let's do a hello world!
#
# In this course, we will use a library called `NetworkX`. Let's first import it.

# %%
import networkx as nx

# %% [markdown]
# After importing the library, let's create a graph

# %%
G = nx.Graph()

# %% [markdown]
# Then, add some nodes and weighted edges to this graph

# %%
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'D', weight=2)
G.add_edge('A', 'C', weight=3)
G.add_edge('C', 'D', weight=4)

# %% [markdown]
# We can visalize this graph using `matplotlib`

# %%
import matplotlib.pyplot as plt

pos=nx.spring_layout(G)
nx.draw(G, pos, with_labels=1, node_size=800)
edge_labels=nx.draw_networkx_edge_labels(G,pos)

# %% [markdown]
# Now, let's search for the shortest path of Graph G, from `node A` to `node D` based on the weights we specified

# %%
nx.shortest_path(G, 'A', 'D', weight='weight')
# Out:
# ['A', 'B', 'D']

# %% [markdown]
# Congrats! That's a very simple example of NetworkX. Try modify the code above and see what you get.

# %% [markdown]
# # 3D Visualization

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
